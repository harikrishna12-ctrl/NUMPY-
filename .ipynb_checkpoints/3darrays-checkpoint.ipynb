# %%
import numpy as np

# %%
arr = np.array([[[1,2,3],[2,3,4],[7,8,5]],[[1,2,3],[7,5,4],[4,4,5]]])
print(arr,arr.shape)
#indexing where we can find which number we wnat
print(arr[0,0,0])

#slicing means like if we want a rows it will be easy while doing slicing
# Out:
# [[[1 2 3]
#   [2 3 4]
#   [7 8 5]]
#
#  [[1 2 3]
#   [7 5 4]
#   [4 4 5]]] (2, 3, 3)
# 1
