# %%
import numpy as np
import time

# %%
arr =np.array([1,2,3,4,6])
print(arr,type(arr))
# Out:
# [1 2 3 4 6] <class 'numpy.ndarray'>

# %%
# execution performance
size= 1_00_000
py_list =list(range(size))
start = time.time()
sq_list=[x**2 for x in py_list]
end = time.time()
print(f"the time is {end-start}")

#num py arrays
array=np.array(py_list)
start =time.time()
sq_array=array ** 2
end= time.time()
print(f"the time of np is {end-start}")
# Out:
# the time is 0.022275924682617188
# the time of np is 0.0006880760192871094

# %%
#MEMORY
import sys

print(f"python list size = {sys.getsizeof(py_list)*len(py_list)} bytes")
print(f"numpy arrays  = {array.nbytes} bytes")
# Out:
# python list size = 80005600000 bytes
# numpy arrays  = 800000 bytes
